# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\humay\OneDrive\Desktop\Data Science\Flip Robo Internship\Customer Retention\customer_retention_coded_dataset.xlsx')
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df_new=df.iloc[:,[0,1,13,19,23,28,29,30,31,33,ArithmeticError34,36,38,40,42,43,44,45,46]].copy()
df_new
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      14 How much time do you explore the e- retail store before making a purchase decision?                                                                     \
# 0                                                    3
# 1                                                    5
# 2                                                    4
# 3                                                    3
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_new.plot.box()
# Out:
# <AxesSubplot:>

# %%
df_new.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 14 How much time do you explore the e- retail s...               0.139327
# 20 Complete information on listed seller and pr...               0.079679
# 24 User friendly Interface of the website                        0.231970
# 29 Responsiveness, availability of several comm...               0.029508
# 30 Online shopping gives monetary benefit and d...               0.164411
# 31 Enjoyment is derived from shopping online                     0.189852
# 32 Shopping online is convenient and flexible                    0.234597
# 34 Gaining access to loyalty programs is a bene...               0.113073
# 35 Displaying quality Information on the websit...               0.285572
# 37 Net Benefit derived from shopping online can...               0.347038
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df_new.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df1 = pd.read_excel(r'C:\Users\humay\OneDrive\Desktop\Data Science\Flip Robo Internship\Customer Retention\customer_retention_dataset1.xlsx')
df1
# Out:
#      1Gender of respondent  2 How old are you?   Utilitarian value  \
# 0                        0                    3           2.444444
# 1                        1                    2           4.222222
# 2                        1                    2           4.000000
# 3                        0                    2           3.000000
# 4                        1                    2           3.777778
# ..                     ...                  ...                ...
# 264                      1                    2           3.000000
# 265                      1                    3           3.888889
# 266                      1                    4           3.666667
# 267                      1                    1           3.666667
# 268                      1                    4           4.222222
#
#      Hedonic value
# 0            4.250
# 1            4.500
# 2            4.125
# 3            3.750
# 4            3.375
# ..             ...
# ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of      1Gender of respondent  2 How old are you?   Utilitarian value  \
# 0                        0                    3           2.444444
# 1                        1                    2           4.222222
# 2                        1                    2           4.000000
# 3                        0                    2           3.000000
# 4                        1                    2           3.777778
# ..                     ...                  ...                ...
# 264                      1                    2           3.000000
# 265                      1                    3           3.888889
# 266                      1                    4           3.666667
# 267                      1                    1           3.666667
# 268                      1                    4           4.222222
#
#      Hedonic value
# 0            4.250
# 1            4.500
# 2            4.125
# 3            3.750
# 4            3.375
# ...

# %%
df1.corr()
# Out:
#                        1Gender of respondent  2 How old are you?   \
# 1Gender of respondent               1.000000            -0.034449
# 2 How old are you?                 -0.034449             1.000000
# Utilitarian value                   0.375094             0.191353
# Hedonic value                       0.092724            -0.151081
#
#                        Utilitarian value  Hedonic value
# 1Gender of respondent           0.375094       0.092724
# 2 How old are you?              0.191353      -0.151081
# Utilitarian value               1.000000       0.373527
# Hedonic value                   0.373527       1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df1.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x= "Utilitarian value",data=df1)
# Out:
# <AxesSubplot:xlabel='Utilitarian value'>

# %%
sns.violinplot(x= "Hedonic value",data=df1)
# Out:
# <AxesSubplot:xlabel='Hedonic value'>

# %%
sns.countplot(x= "Utilitarian value",data=df1)
# Out:
# <AxesSubplot:xlabel='Utilitarian value', ylabel='count'>

# %%
sns.countplot(x= "Hedonic value",data=df1)
# Out:
# <AxesSubplot:xlabel='Hedonic value', ylabel='count'>

# %%
sns.swarmplot(x= "Utilitarian value",data=df1)
# Out:
# <AxesSubplot:xlabel='Utilitarian value'>

# %%
sns.swarmplot(x= "Hedonic value",data=df1)
# Out:
# C:\Users\humay\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Hedonic value'>

# %%
sns.set(style = "whitegrid")
ax=sns.stripplot(x='1Gender of respondent',y='Utilitarian value',data=df1)
plt.title('Graph')
plt.show()

# %%
sns.set(style = "whitegrid")
ax=sns.stripplot(x='1Gender of respondent',y='Hedonic value',data=df1)
plt.title('Graph')
plt.show()
